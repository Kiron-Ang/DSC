# %% [markdown]
# <a href="https://colab.research.google.com/github/Kiron-Ang/DSC/blob/main/vaccination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Print R version
R.version.string

# Install RSocrata
# github.com/chicago/rsocrata
install.packages("RSocrata")

# Install ggplot2
install.packages("ggplot2")
# Out:
# [1] "R version 4.4.2 (2024-10-31)"
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘plyr’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Load RSocrata
library("RSocrata")

# Load ggplot2
library(ggplot2)

# Set plot width and plot height
options(repr.plot.width=15, repr.plot.height=15)

# Read data
# dev.socrata.com/foundry/data.cdc.gov/ee48-w5t6
# data.cdc.gov/Teen-Vaccinations/Vaccination-Coverage-among-Adolescents-13-17-Years/ee48-w5t6
data = read.socrata("https://data.cdc.gov/resource/ee48-w5t6.json")

# Print data dimensions
dim(data)

# Print first 6 data lines
head(data)
# Out:
# [1] 27565    10
#   vaccine         dose                       geography_type     geography
# 1 HPV             ≥1 Dose, Males             States/Local Areas New York
# 2 Tetanus         ≥1 Dose Tdap               States/Local Areas New York
# 3 Tetanus         ≥1 Dose Td or Tdap         States/Local Areas New York
# 4 ≥1 Dose MenACWY                            States/Local Areas New York
# 5 HPV             ≥1 Dose, Males and Females States/Local Areas New York
# 6 HPV             Up-to-Date, Males          States/Local Areas New York
#   year_season dimension_type dimension   coverage_estimate X_95_ci
# 1 2023        Age            13-17 Years 81.5              75.2 to 86.5
# 2 2023        Age            13-17 Years 90.2              86.8 to 92.8
# 3 2023        Age            13-17 Years 93.6              90.9 to 95.5
# 4 2023        Age            13-17 Years 95.3              92.7 to 97.0
# 5 2023        Age            13-17 Years 79.4              74.8 to 83.3
# 6 2023        Age            13-17 Years 67.8              60.8 to 74.2
#   population_sample_size
# 1 289
# 2 559
# 3 559
# 4 559
# 5 559
# 6 289

# %%
# Convert coverage_estimate to numeric
data$coverage_estimate = as.numeric(data$coverage_estimate)

# Print unique vaccines
unique(data$vaccine)
# Out:
# Warning message:
# “NAs introduced by coercion”
# [1] "HPV"             "Tetanus"         "≥1 Dose MenACWY" "≥3 Doses HepB"
# [5] "≥2 Doses MMR"    "Varicella"       "≥2 Doses Hep A"

# %%
# Filter data
data = data[data$vaccine %in% c("HPV", "Tetanus", "≥1 Dose MenACWY"), ]

# Print data dimensions
dim(data)
# Out:
# [1] 18953    10

# %%
# Print vaccines and doses in order
unique(data[c("vaccine", "dose")][order(data$vaccine), ])
# Out:
#       vaccine
# 4     ≥1 Dose MenACWY
# 1     HPV
# 5     HPV
# 6     HPV
# 7     HPV
# 8     HPV
# 19    HPV
# 23    HPV
# 82    HPV
# 96    HPV
# 243   HPV
# 244   HPV
# 419   HPV
# 21687 HPV
# 2     Tetanus
# 3     Tetanus
#       dose
# 4
# 1     ≥1 Dose, Males
# 5     ≥1 Dose, Males and Females
# 6     Up-to-Date, Males
# 7     ≥1 Dose, Females
# 8     Up-to-Date, Males and Females
# 19    Up-to-Date, Females
# 23    ≥2 Doses, Females
# 82    ≥3 Doses, Females
# 96    ≥3 Doses, Males and Females
# 243   ≥2 Doses, Males and Females
# 244   ≥2 Doses, Males
# 419   ≥3 Doses, Males
# 21687 Series Completion (3 Dose) Among HPV Vaccination Initiators, Females
# 2     ≥1 Dose Tdap
# 3     ≥1 Dose Td or Tdap

# %%
# Print unique dimension types
unique(data$dimension_type)
# Out:
# [1] "Age"                "Insurance Coverage" "Poverty"
# [4] "Race and Ethnicity" "Urbanicity"         "Overall"

# %%
# Filter data
data = data[data$dimension_type == "Age", ]

# Print data dimensions
dim(data)
# Out:
# [1] 15715    10

# %%
# Print unique dimensions
unique(data$dimension)
# Out:
# [1] "13-17 Years" "13-15 Years"

# %%
# Filter data
data = data[data$dimension == "13-17 Years", ]

# Print data dimensions
dim(data)
# Out:
# [1] 11294    10

# %%
# Print first 6 data lines
head(data)
# Out:
#   vaccine         dose                       geography_type     geography
# 1 HPV             ≥1 Dose, Males             States/Local Areas New York
# 2 Tetanus         ≥1 Dose Tdap               States/Local Areas New York
# 3 Tetanus         ≥1 Dose Td or Tdap         States/Local Areas New York
# 4 ≥1 Dose MenACWY                            States/Local Areas New York
# 5 HPV             ≥1 Dose, Males and Females States/Local Areas New York
# 6 HPV             Up-to-Date, Males          States/Local Areas New York
#   year_season dimension_type dimension   coverage_estimate X_95_ci
# 1 2023        Age            13-17 Years 81.5              75.2 to 86.5
# 2 2023        Age            13-17 Years 90.2              86.8 to 92.8
# 3 2023        Age            13-17 Years 93.6              90.9 to 95.5
# 4 2023        Age            13-17 Years 95.3              92.7 to 97.0
# 5 2023        Age            13-17 Years 79.4              74.8 to 83.3
# 6 2023        Age            13-17 Years 67.8              60.8 to 74.2
#   population_sample_size
# 1 289
# 2 559
# 3 559
# 4 559
# 5 559
# 6 289

# %%
# Print unique geography types
unique(data$geography_type)
# Out:
# [1] "States/Local Areas"   "HHS Regions/National"

# %%
# Filter data
data = data[data$geography_type == "States/Local Areas", ]

# Print data dimensions
dim(data)
# Out:
# [1] 9507   10

# %%
# Print unique geographies
unique(data$geography)
# Out:
#  [1] "New York"             "New Hampshire"        "Colorado"
#  [4] "Nebraska"             "IL-Rest of state"     "IL-City of Chicago"
#  [7] "PA-Philadelphia"      "PA-Rest of state"     "U.S. Virgin Islands"
# [10] "TX-Rest of state"     "Minnesota"            "Florida"
# [13] "Oklahoma"             "Nevada"               "Mississippi"
# [16] "Montana"              "Tennessee"            "Missouri"
# [19] "Washington"           "Guam"                 "Maine"
# [22] "Kansas"               "Alabama"              "Utah"
# [25] "California"           "Alaska"               "Kentucky"
# [28] "Delaware"             "Texas"                "Idaho"
# [31] "Virginia"             "Iowa"                 "Hawaii"
# [34] "Wyoming"              "Arkansas"             "Georgia"
# [37] "South Dakota"         "Connecticut"          "Oregon"
# [40] "Rhode Island"         "New Mexico"           "Michigan"
# [43] "Louisiana"            "West Virginia"        "Massachusetts"
# [46] "District of Columbia" "TX-City of Houston"   "TX-Bexar County"
# [49] "Pennsylvania"         "North Carolina"       "Puerto Rico"
# [52] "Maryland"             "New Jersey"           "NY-City of New York"
# [55] "NY-Rest of state"     "North Dakota"         "TX-Dallas County"
# [58] "TX-El Paso County"    "TX-Tarrant County"    "TX-Hidalgo County"
# [61] "TX-Travis County"     "Wisconsin"            "Illinois"
# [64] "Ohio"                 "Arizona"              "South Carolina"
# [67] "Indiana"              "Vermont"

# %%
# List of all 50 states and the District of Columbia
# These are areas with electoral college votes in the 2024 election
# www.archives.gov/electoral-college/2024
states = c("Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut",
            "Delaware", "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana",
            "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts",
            "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska",
            "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina",
            "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island",
            "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Vermont",
            "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming", "District of Columbia")

# Filter data for all 50 states and the District of Columbia
data = data[data$geography %in% states, ]

# Print data dimensions
dim(data)
# Out:
# [1] 7702   10

# %%
# Print unique year seasons
unique(data$year_season)
# Out:
#  [1] "2023" "2022" "2020" "2018" "2019" "2021" "2014" "2015" "2013" "2017"
# [11] "2016" "2011" "2012" "2010" "2008" "2009"

# %%
# HPV data
hpv = data[data$vaccine == "HPV" & data$dose == "≥1 Dose, Males and Females", ]

# Print HPV data dimensions
dim(hpv)

# MenACWY data
menacwy = data[data$vaccine == "≥1 Dose MenACWY", ]

# Print MenACWY data dimensions
dim(menacwy)

# Tetanus data
tetanus = data[data$vaccine == "Tetanus" & data$dose == "≥1 Dose Td or Tdap", ]

# Print Tetanus data dimensions
dim(tetanus)
# Out:
# [1] 408  10
# [1] 816  10
# [1] 816  10

# %%
# Create HPV histograms with discrete y-axis
ggplot(hpv, aes(x = coverage_estimate)) +
  geom_histogram(binwidth = 3, fill = "orange", color = "black") +
  labs(title = "HPV Coverage Estimates",
       x = "Coverage Estimate (%)",
       y = "Number of States") +
  theme_classic() +
  theme(text = element_text(size = 25),
        plot.title = element_text(hjust = 0.5, face = "bold", margin = margin(b = 25)),
        panel.spacing = unit(2, "lines"),
        plot.margin = margin(20, 20, 20, 20),
        axis.title.x = element_text(margin = margin(t = 25)),
        axis.title.y = element_text(margin = margin(r = 25))) +
  facet_wrap(~ year_season, scales = "free_y") +
  scale_y_continuous(breaks = seq(0, max(hpv$coverage_estimate), by = 2),
                     labels = as.character(seq(0, max(hpv$coverage_estimate), by = 2)))
# Out:
# plot without title

# %%
# Create MenACWY histograms with discrete y-axis
ggplot(menacwy, aes(x = coverage_estimate)) +
  geom_histogram(binwidth = 3, fill = "orange", color = "black") +
  labs(title = "MenACWY Coverage Estimates",
       x = "Coverage Estimate (%)",
       y = "Number of States") +
  theme_classic() +
  theme(text = element_text(size = 25),
        plot.title = element_text(hjust = 0.5, face = "bold", margin = margin(b = 25)),
        panel.spacing = unit(2, "lines"),
        plot.margin = margin(20, 20, 20, 20),
        axis.title.x = element_text(margin = margin(t = 25)),
        axis.title.y = element_text(margin = margin(r = 25))) +
  facet_wrap(~ year_season, scales = "free_y") +
  scale_y_continuous(breaks = seq(0, max(hpv$coverage_estimate), by = 2),
                     labels = as.character(seq(0, max(hpv$coverage_estimate), by = 2)))
# Out:
# plot without title

# %%
# Create Tetanus histograms with discrete y-axis
ggplot(tetanus, aes(x = coverage_estimate)) +
  geom_histogram(binwidth = 3, fill = "orange", color = "black") +
  labs(title = "Tetanus Coverage Estimates",
       x = "Coverage Estimate (%)",
       y = "Number of States") +
  theme_classic() +
  theme(text = element_text(size = 25),
        plot.title = element_text(hjust = 0.5, face = "bold", margin = margin(b = 25)),
        panel.spacing = unit(2, "lines"),
        plot.margin = margin(20, 20, 20, 20),
        axis.title.x = element_text(margin = margin(t = 25)),
        axis.title.y = element_text(margin = margin(r = 25))) +
  facet_wrap(~ year_season, scales = "free_y") +
  scale_y_continuous(breaks = seq(0, max(hpv$coverage_estimate), by = 2),
                     labels = as.character(seq(0, max(hpv$coverage_estimate), by = 2)))
# Out:
# plot without title

# %%
# Read Influenza data
# dev.socrata.com/foundry/data.cdc.gov/vh55-3he6
# data.cdc.gov/Flu-Vaccinations/Influenza-Vaccination-Coverage-for-All-Ages-6-Mont/vh55-3he6
influenza = read.socrata("https://data.cdc.gov/resource/vh55-3he6.json")

# Print Influenza data dimensions
dim(influenza)

# Print first 6 data lines
head(influenza)
# Out:
# [1] 217585     11
#   vaccine            geography_type     geography       fips year_season month
# 1 Seasonal Influenza States/Local Areas TX-Bexar County 151  2017-18     1
# 2 Seasonal Influenza States/Local Areas TX-Bexar County 151  2020-21     1
# 3 Seasonal Influenza States/Local Areas TX-Bexar County 151  2017-18     1
# 4 Seasonal Influenza States/Local Areas TX-Bexar County 151  2020-21     1
# 5 Seasonal Influenza States/Local Areas TX-Bexar County 151  2018-19     1
# 6 Seasonal Influenza States/Local Areas TX-Bexar County 151  2018-19     2
#   dimension_type      dimension       coverage_estimate X_95_ci
# 1 6 Months - 17 Years Medical Setting 88.9              86.3 to 91.1
# 2 6 Months - 17 Years Medical Setting 79.1              75.9 to 82.0
# 3 6 Months - 17 Years Pharmacy/Store  8.4               6.5 to 10.8
# 4 6 Months - 17 Years Pharmacy/Store  18.2              15.5 to 21.3
# 5 Age                 50-64 Years     46.8              32.1 to 61.5 ‡
# 6 Age                 50-64 Years     50.1              34.8 to 65.4 ‡
#   population_sample_size
# 1 1060
# 2 1253
# 3 1060
# 4 1253
# 5 115
# 6 115
