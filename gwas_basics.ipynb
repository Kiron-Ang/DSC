# %% [markdown]
# <a href="https://colab.research.google.com/github/Kiron-Ang/DSC/blob/main/gwas_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This command displays the version of Python currently being used in the environment
# !python -V
# Out:
# Python 3.10.12

# %%
# Import the pandas library, which is used for data manipulation and analysis
import pandas as pd

# Read the file "ldl.assoc.linear" into a pandas DataFrame
# The function pd.read_table is used to read the data from the file.
# The 'sep="\s+"' argument specifies that the columns are separated by one or more spaces (whitespace).
results = pd.read_table("ldl.assoc.linear", sep="\s+")

# Display the contents of the 'results' DataFrame
results
# Out:
#        CHR         SNP     BP A1 TEST  NMISS      BETA      STAT             P
# 0        1  rs15186857      1  H  ADD  11378 -0.005212  -0.31400  7.535000e-01
# 1        1  rs22173183      2  H  ADD  11378 -0.001176  -0.07681  9.388000e-01
# 2        1  rs26066770      3  H  ADD  11378 -0.005174  -0.38120  7.031000e-01
# 3        1  rs16959877      4  L  ADD  11378 -0.010340  -0.75460  4.505000e-01
# 4        1  rs21930324      5  H  ADD  11378  0.018510   1.26800  2.050000e-01
# ...    ...         ...    ... ..  ...    ...       ...       ...           ...
# 10571    1  rs22992630  10572  H  ADD  11378  0.262400   9.83000  1.034000e-22
# 10572    1  rs18904265  10573  L  ADD  11378 -0.155500 -11.08000  2.206000e-28
# 10573    1  rs26364861  10574  H  ADD  11378  0.205700  10.93000  1.099000e-27
# 10574    1  rs19166798  10575  L  ADD  11378 -0.138300  -8.82500  1.249000e-18
# 10575    1  rs12590938  10576  H  ADD  11378  0.140200  10.61000  3.536000e-26
#
# ...

# %%
# This filters the 'results' DataFrame to include only rows where the 'P' column has values less than 0.05
# This is commonly used for statistical significance testing (e.g., p-value threshold for significance)
results[results.P < 0.05]
# Out:
#        CHR         SNP     BP A1 TEST  NMISS     BETA    STAT             P
# 24       1  rs20881573     25  H  ADD  11378  0.04149   2.757  5.836000e-03
# 46       1  rs25443630     47  L  ADD  11378 -0.04511  -2.498  1.251000e-02
# 86       1  rs17747778     87  H  ADD  11378  0.02968   2.018  4.362000e-02
# 110      1  rs15981352    111  H  ADD  11378 -0.02699  -2.043  4.108000e-02
# 114      1  rs18460669    115  H  ADD  11378  0.03789   1.967  4.919000e-02
# ...    ...         ...    ... ..  ...    ...      ...     ...           ...
# 10571    1  rs22992630  10572  H  ADD  11378  0.26240   9.830  1.034000e-22
# 10572    1  rs18904265  10573  L  ADD  11378 -0.15550 -11.080  2.206000e-28
# 10573    1  rs26364861  10574  H  ADD  11378  0.20570  10.930  1.099000e-27
# 10574    1  rs19166798  10575  L  ADD  11378 -0.13830  -8.825  1.249000e-18
# 10575    1  rs12590938  10576  H  ADD  11378  0.14020  10.610  3.536000e-26
#
# [652 rows x 9 columns]

# %%
# This filters the 'results' DataFrame to include only rows where the 'P' column has values less than 5e-8
# It then sorts the filtered DataFrame by the 'P' column in ascending order.
# Finally, it selects the first few rows (using head()), gets the 'SNP' column, and converts it into a list of SNP identifiers.
results[results.P < 5e-8].sort_values(by = "P").SNP.head().tolist()
# Out:
# ['rs12740374', 'rs1182628', 'rs2703384', 'rs6938087', 'rs1240260']
